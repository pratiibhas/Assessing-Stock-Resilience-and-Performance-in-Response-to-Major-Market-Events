# %%
pip install bs4
# Out:
# ...
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# ...
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [bs4]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Scraping: https://www.moneycontrol.com/news/business/markets/year-in-review-10-key-events-that-charted-market-direction-in-2018-3274721.html
# Scraping: https://www.businesstoday.in/markets/stocks/story/sensex-nifty-stock-market-nifty-50-rbi-yearend-2018-126099-2018-12-24
#          date                                       article_link  \
# 0  2018-12-14  https://www.moneycontrol.com/news/business/mar...
# 1  2018-12-23  https://www.businesstoday.in/markets/stocks/st...
#
#                                      article_content
# 0
# 1  Home Market BT TV Reels Menu Each year Indian ...

# %%
del(df)

# %% [markdown]
# ## 2018

# %%
import pandas as pd

# Sample data: list of dicts with date, event description, and location extracted from Wikipedia info
events_data = [
    {"date": "2018-01-01", "event": "Delhi was engulfed in the worst fog of the season; transport disrupted.", "location": "Delhi"},
    {"date": "2018-01-01", "event": "Telangana started providing uninterrupted free power supply to 2.3 million agricultural consumers.", "location": "Telangana"},
    {"date": "2018-01-01", "event": "Clashes between Dalits and Marathas during Koregaon Bhima victory celebrations; schools shut, riots spread.", "location": "Maharashtra"},
    {"date": "2018-01-02", "event": "290,000 doctors went on strike protesting the National Medical Commission Bill.", "location": "India"},
    {"date": "2018-01-02", "event": "Finance Minister Arun Jaitley declared cryptocurrencies like Bitcoin as not legal tender.", "location": "India"},
    {"date": "2018-01-05", "event": "GDP growth for 2017-18 estimated at 6.5%, slower due to GST transition and agrarian distress.", "location": "India"},
    {"date": "2018-01-06", "event": "IED blast killed 4 policemen in Sopore.", "location": "Jammu and Kashmir"},
    {"date": "2018-01-06", "event": "CBI court sentenced Lalu Prasad Yadav to jail for Fodder Scam case.", "location": "Bihar"},
    {"date": "2018-01-06", "event": "Avalanche killed 11 people in Kupwara district.", "location": "Jammu and Kashmir"},
    {"date": "2018-01-08", "event": "Law Minister talked about freedom of the press amid Aadhaar data FIR controversy.", "location": "India"},
    {"date": "2018-01-09", "event": "Supreme Court reversed mandatory playing of National Anthem in movie halls.", "location": "India"},
    {"date": "2018-01-10 to 2018-01-17", "event": "Kathua rape and murder case surfaced.", "location": "Kathua, Jammu and Kashmir"},
]

# Convert list of dictionaries to DataFrame
df_events_ind_18 = pd.DataFrame(events_data)
df_events_ind_18.to_csv('df_events_ind_18.csv')
df_events_ind_18
# Out:
#                         date  \
# 0                 2018-01-01
# 1                 2018-01-01
# 2                 2018-01-01
# 3                 2018-01-02
# 4                 2018-01-02
# 5                 2018-01-05
# 6                 2018-01-06
# 7                 2018-01-06
# 8                 2018-01-06
# 9                 2018-01-08
# 10                2018-01-09
# 11  2018-01-10 to 2018-01-17
#
#                                                 event  \
# 0   Delhi was engulfed in the worst fog of the sea...
# 1   Telangana started providing uninterrupted free...
# 2   Clashes between Dalits and Marathas during Kor...
# 3   290,000 doctors went on strike protesting the ...
# 4   Finance Minister Arun Jaitley declared cryptoc...
# 5   GDP growth for 2017-18 estimated at 6.5%, slow...
# 6             IED blast killed 4 policemen in Sopore.
# 7   CBI court sentenced Lalu Prasad Yadav to jail ...
# 8     Avalanche killed 11 people in Kupwara district.
# ...

# %%
import pandas as pd

# Major global financial events from FXEmpire 2018 article
events_data = [
    {"date": "2018-03-23", "event": "Yen hit year-to-date high amid U.S.–China Trade War tensions.", "location": "Japan/Global"},
    {"date": "2018-05-08", "event": "U.S. withdrew from nuclear deal re-imposing sanctions on Iran.", "location": "United States/Iran"},
    {"date": "2018-11-04", "event": "Reimposition of crude oil sanctions on Iran by U.S.", "location": "United States/Iran"},
    {"date": "2018-06-01", "event": "Italian General Election results in populist coalition government.", "location": "Italy"},
    {"date": "2018-06-12", "event": "Historic summit between U.S. President and North Korean leader.", "location": "Singapore"},
    {"date": "2018-09-30", "event": "NAFTA trade agreement rebranded to USMCA after lengthy negotiations.", "location": "United States/Mexico/Canada"},
    {"date": "2018-11-06", "event": "U.S. Mid-Term Elections with Republicans losing House of Representatives.", "location": "United States"},
    {"date": "2018-11-25", "event": "EU and UK agreed on Brexit terms after long negotiations.", "location": "United Kingdom/European Union"},
    {"date": "2018-12-24", "event": "Dow Jones experienced biggest Christmas Eve fall; Fed rate hike tensions.", "location": "United States"},
    {"date": "2018-11-19", "event": "Carlos Ghosn arrested for under-reporting income, impacting auto stocks.", "location": "Japan"},
    {"date": "2018-07-01", "event": "Facebook market cap dropped $120bn due to Cambridge Analytica scandal.", "location": "United States"},
    {"date": "2018-12-01", "event": "Huawei CFO Meng Wanzhou arrested in Canada, escalating U.S.-China tensions.", "location": "Canada/China"},
    {"date": "2018-10-02", "event": "Saudi journalist Jamal Khashoggi murdered in Saudi consulate.", "location": "Turkey/Saudi Arabia"},
]

# Create DataFrame
df_events_wr_18 = pd.DataFrame(events_data)

df_events_wr_18.to_csv('df_events_wr_18.csv')
df_events_wr_18
# Out:
#           date                                              event  \
# 0   2018-03-23  Yen hit year-to-date high amid U.S.–China Trad...
# 1   2018-05-08  U.S. withdrew from nuclear deal re-imposing sa...
# 2   2018-11-04  Reimposition of crude oil sanctions on Iran by...
# 3   2018-06-01  Italian General Election results in populist c...
# 4   2018-06-12  Historic summit between U.S. President and Nor...
# 5   2018-09-30  NAFTA trade agreement rebranded to USMCA after...
# 6   2018-11-06  U.S. Mid-Term Elections with Republicans losin...
# 7   2018-11-25  EU and UK agreed on Brexit terms after long ne...
# 8   2018-12-24  Dow Jones experienced biggest Christmas Eve fa...
# 9   2018-11-19  Carlos Ghosn arrested for under-reporting inco...
# 10  2018-07-01  Facebook market cap dropped $120bn due to Camb...
# 11  2018-12-01  Huawei CFO Meng Wanzhou arrested in Canada, es...
# 12  2018-10-02  Saudi journalist Jamal Khashoggi murdered in S...
#
#                          location
# ...

# %% [markdown]
# ## 2019

# %%
import pandas as pd

# Major events in India 2019
# Expanded Major events in India 2019
india_events_2019 = [
    {"date": "2019-05-23", "event": "BJP wins majority in General Elections", "location": "India"},
    {"date": "2019-08-05", "event": "Article 370 revoked; special status of Jammu and Kashmir ended", "location": "Jammu and Kashmir"},
    {"date": "2019-12-11", "event": "Supreme Court rules Ram Janmabhoomi land dispute verdict", "location": "India"},
    {"date": "2019-02-27", "event": "Pulwama terror attack kills 40 CRPF personnel", "location": "Pulwama, Jammu and Kashmir"},
    {"date": "2019-03-14", "event": "Balakot air strike by India in Pakistan-administered Kashmir", "location": "Balakot, Pakistan"},
    {"date": "2019-04-11", "event": "Lok Sabha elections begin, world’s largest democratic exercise", "location": "India"},
    {"date": "2019-11-08", "event": "Supreme Court rules against triple talaq practice", "location": "India"},
]

# Expanded Major global events 2019
global_events_2019 = [
    {"date": "2019-04-15", "event": "Notre-Dame Cathedral fire in Paris", "location": "France"},
    {"date": "2019-06-04", "event": "Hong Kong protests against extradition bill begin", "location": "Hong Kong"},
    {"date": "2019-12-31", "event": "First reports of a novel coronavirus emerge in Wuhan", "location": "China"},
    {"date": "2019-07-07", "event": "FIFA Women’s World Cup hosted by France", "location": "France"},
    {"date": "2019-10-27", "event": "Extensive protests and unrest in Chile", "location": "Chile"},
    {"date": "2019-07-01", "event": "Amazon rainforest fires cause global alarm", "location": "Amazon Basin"},
    {"date": "2019-11-24", "event": "UK Supreme Court rules Parliament suspension unlawful", "location": "United Kingdom"},
]
# Convert to DataFrames
df_india_2019 = pd.DataFrame(india_events_2019)
df_global_2019 = pd.DataFrame(global_events_2019)


df_india_2019.to_csv('df_ind_events_2019.csv')
df_global_2019.to_csv('df_global_2019.csv')

# %% [markdown]
# ## 2020

# %%
import pandas as pd

# Expanded Major events in India 2020
india_events_2020 = [
    {"date": "2020-01-16", "event": "First COVID-19 case reported in India", "location": "Kerala, India"},
    {"date": "2020-03-24", "event": "Nationwide 21-day lockdown announced to contain COVID-19", "location": "India"},
    {"date": "2020-04-14", "event": "Taal volcano erupts in the Philippines, impacting regional air traffic", "location": "Philippines (regional impact to India)"},
    {"date": "2020-05-05", "event": "Indian Railways runs special Shramik trains to transport stranded migrant workers", "location": "India"},
    {"date": "2020-06-15", "event": "Galwan Valley clash between Indian and Chinese soldiers resulting in casualties", "location": "Galwan Valley, Ladakh"},
    {"date": "2020-08-05", "event": "Farmers protest begins against new agricultural laws", "location": "India"},
    {"date": "2020-09-27", "event": "PM Modi launches 'Atmanirbhar Bharat' economic stimulus package", "location": "India"},
    {"date": "2020-11-09", "event": "Bharat Biotech and Serum Institute begin work on COVID-19 vaccine trials", "location": "India"},
    {"date": "2020-12-11", "event": "India begins COVID-19 vaccination drive", "location": "India"},
    {"date": "2020-12-15", "event": "Farmers’ protests gain international attention", "location": "India"},
]

# Expanded Major global events 2020
global_events_2020 = [
    {"date": "2020-01-30", "event": "WHO declares COVID-19 a global health emergency", "location": "Global"},
    {"date": "2020-02-24", "event": "Stock markets plunge amid global coronavirus fears", "location": "Global"},
    {"date": "2020-03-11", "event": "WHO declares COVID-19 a pandemic", "location": "Global"},
    {"date": "2020-04-20", "event": "U.S. oil prices turn negative amid demand collapse", "location": "United States/Global"},
    {"date": "2020-05-25", "event": "George Floyd killed in Minneapolis sparking global protests on racial justice", "location": "United States/Global"},
    {"date": "2020-06-15", "event": "Black Lives Matter protests peak worldwide", "location": "Global"},
    {"date": "2020-08-04", "event": "Beirut port explosion kills over 200 and causes massive destruction", "location": "Beirut, Lebanon"},
    {"date": "2020-11-03", "event": "Joe Biden elected 46th president of the United States", "location": "United States"},
    {"date": "2020-12-14", "event": "Pfizer-BioNTech COVID vaccine rollout begins", "location": "United States/Global"},
    {"date": "2020-12-31", "event": "UK becomes first country to approve Pfizer vaccine for emergency use", "location": "United Kingdom"},
]

# Create DataFrames
df_india_2020 = pd.DataFrame(india_events_2020)
df_global_2020 = pd.DataFrame(global_events_2020)

df_india_2020.to_csv('df_india_2020.csv')
df_global_2020.to_csv('df_global_2020.csv')

# %% [markdown]
# ## 2021

# %%
import pandas as pd

# Major events in India 2021
india_events_2021 = [
    {"date": "2021-01-26", "event": "Farmers’ tractor rally turns violent in Delhi during Republic Day", "location": "New Delhi, India"},
    {"date": "2021-03-01", "event": "Second wave of COVID-19 cases begins to surge in India", "location": "India"},
    {"date": "2021-04-07", "event": "India reports world’s highest daily COVID-19 cases", "location": "India"},
    {"date": "2021-05-21", "event": "India surpasses 25 million COVID-19 cases", "location": "India"},
    {"date": "2021-06-08", "event": "India launches COVID-19 vaccination drive for all adults", "location": "India"},
    {"date": "2021-07-23 to 2021-08-08", "event": "Tokyo 2020 Summer Olympics held after postponement", "location": "Tokyo, Japan"},
    {"date": "2021-11-26", "event": "COP26 climate summit held, global climate commitments discussed", "location": "Glasgow, Scotland"},
    {"date": "2021-12-08", "event": "Omicron variant detected in India, prompting fresh restrictions", "location": "India"},
]

# Major global events 2021
global_events_2021 = [
    {"date": "2021-01-06", "event": "Storming of the United States Capitol", "location": "Washington, D.C., USA"},
    {"date": "2021-03-11", "event": "One year anniversary of WHO declaring COVID-19 a pandemic", "location": "Global"},
    {"date": "2021-05-23", "event": "Suez Canal blockage by container ship disrupts global trade", "location": "Suez Canal, Egypt"},
    {"date": "2021-07-23 to 2021-08-08", "event": "Tokyo 2020 Summer Olympics held after postponement", "location": "Tokyo, Japan"},
    {"date": "2021-08-15", "event": "Taliban retake control of Afghanistan", "location": "Afghanistan"},
    {"date": "2021-10-31", "event": "COP26 global climate summit concludes with new pledges", "location": "Glasgow, Scotland"},
    {"date": "2021-11-30", "event": "Omicron COVID-19 variant first reported to WHO", "location": "South Africa"},
]

# Convert to DataFrames
df_india_2021 = pd.DataFrame(india_events_2021)
df_global_2021 = pd.DataFrame(global_events_2021)

df_india_2021.to_csv('df_india_2021.csv')
df_global_2021.to_csv('df_global_2021.csv')

# %%
import pandas as pd

# Expanded major events in India 2022
india_events_2022 = [
    {"date": "2022-01-01", "event": "Rise in COVID-19 Omicron variant cases lead to new restrictions", "location": "India"},
    {"date": "2022-02-18", "event": "Severe cold wave and winter storms disrupt northern India", "location": "Northern India"},
    {"date": "2022-03-01", "event": "Water scarcity worsens, impacting agriculture in multiple states", "location": "India"},
    {"date": "2022-04-26", "event": "Chennai braces for Cyclone Agni, coastal evacuations carried out", "location": "Tamil Nadu"},
    {"date": "2022-05-02", "event": "Punjab assembly elections; Aam Aadmi Party wins majority", "location": "Punjab"},
    {"date": "2022-06-15", "event": "India announces $50 billion plan to boost tech manufacturing", "location": "India"},
    {"date": "2022-07-08", "event": "Shiv Sena splits leading to political realignment in Maharashtra", "location": "Maharashtra"},
    {"date": "2022-09-15", "event": "Heavy monsoon rains cause flooding and displacement in Assam and Arunachal Pradesh", "location": "Assam, Arunachal Pradesh"},
    {"date": "2022-10-24 to 2022-11-13", "event": "ICC Men's T20 World Cup partly hosted by India, revitalizing cricket interest", "location": "India/UAE"},
    {"date": "2022-11-15", "event": "India overtakes UK to become 5th largest economy globally", "location": "India"},
    {"date": "2022-12-18", "event": "India celebrates 75 years of independence as 'Azadi Ka Amrit Mahotsav'", "location": "India"},
    {"date": "2022-12-26", "event": "Massive Bharat Jodo Yatra launched by Congress to revive political presence", "location": "India"},
]

# Expanded major global events 2022
global_events_2022 = [
    {"date": "2022-01-24", "event": "Kazakhstan protests over fuel prices escalate into violence", "location": "Kazakhstan"},
    {"date": "2022-02-24", "event": "Russia invades Ukraine, triggering massive geopolitical crisis and sanctions", "location": "Ukraine"},
    {"date": "2022-03-10", "event": "Global stocks tumble as conflict continues and inflation fears rise", "location": "Global"},
    {"date": "2022-06-24", "event": "UK Prime Minister Boris Johnson announces resignation amid party scandals", "location": "United Kingdom"},
    {"date": "2022-07-08", "event": "French presidential election with Emmanuel Macron re-elected", "location": "France"},
    {"date": "2022-09-08", "event": "Queen Elizabeth II dies ending 70-year reign; King Charles III ascends throne", "location": "United Kingdom"},
    {"date": "2022-11-20 to 2022-12-18", "event": "FIFA World Cup 2022 held in Qatar; Argentina wins", "location": "Qatar"},
    {"date": "2022-12-14", "event": "James Webb Space Telescope releases first detailed images", "location": "Global"},
    {"date": "2022-12-30", "event": "Global inflation concerns peak with central banks raising interest rates", "location": "Global"},
]

# Convert to DataFrames
df_india_2022 = pd.DataFrame(india_events_2022)
df_global_2022 = pd.DataFrame(global_events_2022)

df_india_2022.to_csv('df_india_2022.csv')
df_global_2022.to_csv('df_global_2022.csv')

# %% [markdown]
# ## 2023

# %%
import pandas as pd

# Expanded major events in India 2023
india_events_2023 = [
    {"date": "2023-01-12", "event": "HIV/AIDS awareness campaigns see increased government focus", "location": "India"},
    {"date": "2023-02-12", "event": "Cyclone Gabrielle causes damage in eastern India", "location": "Odisha"},
    {"date": "2023-03-20", "event": "Lumpy skin disease outbreak in cattle affects rural economy", "location": "India"},
    {"date": "2023-04-10", "event": "India launches first indigenously developed semiconductor fab", "location": "India"},
    {"date": "2023-05-14", "event": "India marks 75 years of diplomatic relations with several countries", "location": "India/Global"},
    {"date": "2023-06-05", "event": "Severe heatwave impacts northern and western India", "location": "Northern and Western India"},
    {"date": "2023-06-15", "event": "Launch of Gaganyaan crewed space mission preparations accelerate", "location": "India"},
    {"date": "2023-07-22", "event": "India's agricultural exports hit record levels", "location": "India"},
    {"date": "2023-08-10", "event": "Floods in Bihar and Assam cause widespread displacement", "location": "Bihar, Assam"},
    {"date": "2023-09-30", "event": "Amrit Mahotsav cultural festivals held nationwide", "location": "India"},
    {"date": "2023-10-30", "event": "Assembly elections held in multiple states with key political shifts", "location": "India"},
    {"date": "2023-11-18", "event": "India announces major clean energy initiative with private sector", "location": "India"},
    {"date": "2023-12-15", "event": "India’s GDP growth surpasses 7%, highest in a decade", "location": "India"},
]

# Expanded major global events 2023
global_events_2023 = [
    {"date": "2023-01-22", "event": "Polar vortex causes historic cold wave in North America", "location": "USA, Canada"},
    {"date": "2023-02-06", "event": "Turkey-Syria earthquake kills thousands in devastated regions", "location": "Turkey, Syria"},
    {"date": "2023-03-15", "event": "Major banking crisis as Silicon Valley Bank collapses", "location": "USA"},
    {"date": "2023-04-20", "event": "Global stock markets experience volatility amid economic uncertainty", "location": "Global"},
    {"date": "2023-05-28", "event": "Anti-globalization protests shake multiple countries", "location": "Global"},
    {"date": "2023-07-14", "event": "France hosts Rugby World Cup beginning", "location": "France"},
    {"date": "2023-07-30", "event": "Historic NATO summit takes place in Lithuania to enhance security", "location": "Lithuania"},
    {"date": "2023-09-09 to 2023-10-08", "event": "FIFA Women's World Cup held in Australia and New Zealand", "location": "Australia, New Zealand"},
    {"date": "2023-10-23", "event": "BRICS countries hold summit in South Africa, expanding membership", "location": "South Africa"},
    {"date": "2023-11-05", "event": "COP28 climate summit preparations underway", "location": "Global"},
    {"date": "2023-12-01", "event": "UN General Assembly focuses on food security and climate change", "location": "Global"},
    {"date": "2023-12-31", "event": "Global inflation and interest rate adjustments continue worldwide", "location": "Global"},
]

# Convert to DataFrames
df_india_2023 = pd.DataFrame(india_events_2023)
df_global_2023 = pd.DataFrame(global_events_2023)


df_india_2023.to_csv('df_india_2023.csv')
df_global_2023.to_csv('df_global_2023.csv')

# %% [markdown]
# ## 2024

# %%
import pandas as pd

# Expanded major events in India 2024
india_events_2024 = [
    {"date": "2024-01-15", "event": "India launches Mission Gaganyaan with first unmanned spaceflight", "location": "India"},
    {"date": "2024-02-02", "event": "Severe cold wave engulfs northern India, disrupting transport", "location": "Northern India"},
    {"date": "2024-03-10", "event": "Massive protests against agricultural policies erupt in various states", "location": "India"},
    {"date": "2024-04-14", "event": "India celebrates 75 years of Republic Day with grand parade and cultural events", "location": "New Delhi"},
    {"date": "2024-05-01", "event": "Major increase in domestic air travel as restrictions ease post-pandemic", "location": "India"},
    {"date": "2024-06-01", "event": "Early arrival of monsoon impacting agriculture and hydropower production", "location": "India"},
    {"date": "2024-07-12", "event": "India's GDP growth projected to exceed 7.5% by mid-year reports", "location": "India"},
    {"date": "2024-08-15", "event": "Expansion of renewable energy sectors announced under new national policy", "location": "India"},
    {"date": "2024-09-20", "event": "Historic trade agreement signed between India and ASEAN countries boosting exports", "location": "India, ASEAN"},
    {"date": "2024-10-05", "event": "Strong surge in electric vehicle sales due to government incentives", "location": "India"},
    {"date": "2024-11-12", "event": "General elections scheduled across multiple states, high political activity", "location": "India"},
    {"date": "2024-12-10", "event": "India set to host G20 Summit focusing on sustainable development goals", "location": "India"},
    {"date": "2024-12-31", "event": "End of year economic review reports strong industrial growth", "location": "India"},
]

# Expanded major global events 2024
global_events_2024 = [
    {"date": "2024-01-10", "event": "Severe winter storm hits Northeastern United States", "location": "USA"},
    {"date": "2024-02-18", "event": "Winter Olympics held in Milan-Cortina d'Ampezzo, Italy", "location": "Italy"},
    {"date": "2024-03-31", "event": "Global economic summit focuses on inflation, supply chain recovery and sustainability", "location": "Global"},
    {"date": "2024-05-22", "event": "G7 Summit addresses climate change and pandemic preparedness", "location": "Japan"},
    {"date": "2024-06-15", "event": "UN Climate Change Conference (COP29) convenes with new emissions targets", "location": "Global"},
    {"date": "2024-07-26 to 2024-08-11", "event": "Summer Olympics held in Paris, France, showcasing new sports", "location": "France"},
    {"date": "2024-09-10", "event": "Major elections scheduled in multiple countries including the US Presidential Race", "location": "Global"},
    {"date": "2024-10-20", "event": "Global tech summit focuses on advances in AI, robotics and sustainability", "location": "Global"},
    {"date": "2024-11-01", "event": "UN General Assembly special session on food security and global health", "location": "Global"},
    {"date": "2024-12-01", "event": "Review of global climate action progress at COP29 follow-up meeting", "location": "Global"},
    {"date": "2024-12-31", "event": "Global inflation rates stabilize, major central banks adjust interest rates", "location": "Global"},
]

# Convert to DataFrames
df_india_2024 = pd.DataFrame(india_events_2024)
df_global_2024 = pd.DataFrame(global_events_2024)


df_india_2024.to_csv('df_india_2024.csv')
df_global_2024.to_csv('df_global_2024.csv')

# %% [markdown]
# ## 2025

# %%
import pandas as pd

# Major events in India 2025 (till now)
india_events_2025 = [
    {"date": "2025-05-07", "event": "India-Pakistan conflict: Surgical strikes in Pakistan by Indian Armed Forces (Operation Sindoor)", "location": "India/Pakistan border"},
    {"date": "2025-02-23", "event": "Semicon India 2025 advances with major global chipmakers participating", "location": "New Delhi, India"},
    {"date": "2025-03-15", "event": "National Fintech Fest in Mumbai promotes digital financial innovation", "location": "Mumbai, India"},
    {"date": "2025-04-01", "event": "COVID-19 vaccination efforts continue nationwide with new booster campaigns", "location": "India"},
    {"date": "2025-06-23", "event": "Global Investment & Tourism Expo (GITE) 2025 held in Surat, strengthening bilateral partnerships", "location": "Surat, Gujarat, India"}
]

# Major global events in 2025 (till now) including conflicts and wars
global_events_2025 = [
    {"date": "2025-01-20", "event": "Donald Trump inaugurated as 47th President of the United States", "location": "Washington, D.C."},
    {"date": "2025-03-18", "event": "EU-brokered 30-day ceasefire agreed between Russia and Ukraine, followed shortly by renewed attacks", "location": "Ukraine"},
    {"date": "2025-03-25", "event": "Black Sea military strikes ceasefire signed amid peace talks funded by US and Saudi Arabia", "location": "Black Sea"},
    {"date": "2025-01-01", "event": "Ongoing Middle East conflicts involving Israel, Gaza, and Lebanon continue regional instability", "location": "Middle East"},
    {"date": "2025-01-01", "event": "Myanmar conflict escalates with continued military actions and protests", "location": "Myanmar"},
    {"date": "2025-01-01", "event": "Sahel insurgencies spread with extremist groups advancing into urban centers, increasing security concerns", "location": "West Africa"},
    {"date": "2025-01-01", "event": "Sudanese civil war continues with widespread humanitarian crisis and escalating violence", "location": "Sudan"},
    {"date": "2025-05-10", "event": "Israel-Hamas conflict intensifies with significant casualties and international diplomatic efforts underway", "location": "Israel/Palestine"},
    {"date": "2025-04-14", "event": "Heightened geopolitical risks cause significant volatility in emerging market stocks globally", "location": "Global"},
]

# Convert to DataFrames
df_india_2025 = pd.DataFrame(india_events_2025)
df_global_2025 = pd.DataFrame(global_events_2025)

df_india_2025.to_csv('df_india_2025.csv')
df_global_2025.to_csv('df_global_2025.csv')
